# %%
import pyspark.sql.functions as F

# %%
# %sql
USE CATALOG liquid_telecom;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
raw_data_path = f"/Volumes/liquid_telecom/raw/liquid_telecom_volume/fact/"

df = spark.read.option('header', "true").option("delimeter", ",").csv(raw_data_path)

# add metadata columns
df = df.withColumn("_source_file", F.col("_metadata.file_path")) \
       .withColumn("ingested_at", F.current_timestamp())
       
df.write.format("delta") \
    .mode("overwrite") \
    .option("mergeSchema", "true") \
    .saveAsTable("liquid_telecom.bronze.b_fact_subscriptions_revenue")
