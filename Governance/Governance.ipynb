# %%
"GRANT USAGE ON CATALOG liquid_telecom TO `account users`"
# Out:
# 'GRANT USAGE ON CATALOG liquid_telecom TO `account users`'

# %% [markdown]
# ## **Data Analysts**

# %%
# %sql
GRANT SELECT ON SCHEMA liquid_telecom.gold TO `account users`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## **Data Engineers**

# %%
# Use Databricks SQL to grant privileges on the schema
spark.sql("""
GRANT SELECT, MODIFY
ON SCHEMA liquid_telecom.silver
TO `account users`
""")
spark.sql("""
GRANT SELECT, MODIFY
ON SCHEMA liquid_telecom.gold
TO `account users`
""")
# Out:
# DataFrame[]
